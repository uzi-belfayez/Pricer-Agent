# %%
# imports

import os
import re
import math
import json
from tqdm import tqdm
import random
from dotenv import load_dotenv
from huggingface_hub import login
import numpy as np
import pickle
from openai import OpenAI
import google.generativeai as genai
from sentence_transformers import SentenceTransformer
from datasets import load_dataset
import chromadb
from items import Item
from testing import Tester
import pandas as pd
import numpy as np
from sklearn.ensemble import RandomForestRegressor
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score
import joblib
import time

# %%
# Load it back in again

rf_model = joblib.load('agents/random_forest_model.pkl')

# %%
# Load in the test pickle file:

with open('test.pkl', 'rb') as file:
    test = pickle.load(file)

# %%
QUESTION = "How much does this cost to the nearest dollar?\n\n"
DB = "products_vectorstore"

# %%
client = chromadb.PersistentClient(path=DB)
collection = client.get_or_create_collection('products')

# %%
result = collection.get(include=['embeddings', 'documents', 'metadatas'])
vectors = np.array(result['embeddings'])
documents = result['documents']
prices = [metadata['price'] for metadata in result['metadatas']]

# %%
import importlib
import agents.frontier_agent_gemini
importlib.reload(agents.frontier_agent_gemini) # when u change thhe model file and u want to reload it

from agents.frontier_agent_gemini import FrontierAgentGemini

# %%
import google.generativeai as genai
from agents.specialist_agent import SpecialistAgent
from agents.frontier_agent_gemini import FrontierAgentGemini
from agents.random_forest_agent import RandomForestAgent

# %%
specialist = SpecialistAgent()
frontier = FrontierAgentGemini(collection)
random_forest = RandomForestAgent()

# %%
def description(item):
    return item.prompt.split("to the nearest dollar?\n\n")[1].split("\n\nPrice is $")[0]

# %%
def rf(item):
    return random_forest.price(description(item))

# %%
Tester.test(rf, test)
# Out:
# 1: Guess: $266.73 Truth: $374.41 Error: $107.68 SLE: 0.11 Item: OEM AC Compressor w/A/C Repair Kit For F...
# 2: Guess: $195.58 Truth: $225.11 Error: $29.53 SLE: 0.02 Item: Motorcraft YB3125 Fan Clutch
# 3: Guess: $244.79 Truth: $61.68 Error: $183.11 SLE: 1.87 Item: Dorman 603-159 Front Washer Fluid Reserv...
# 4: Guess: $330.10 Truth: $599.99 Error: $269.89 SLE: 0.36 Item: HP Premium 17.3-inch HD Plus Touchscreen...
# 5: Guess: $228.19 Truth: $16.99 Error: $211.20 SLE: 6.48 Item: 5-Position Super Switch Pickup Selector ...
# 6: Guess: $115.24 Truth: $31.99 Error: $83.25 SLE: 1.59 Item: Horror Bookmarks, Resin Horror Bookmarks...
# 7: Guess: $276.25 Truth: $101.79 Error: $174.46 SLE: 0.98 Item: SK6241 - Stinger 4 Gauge 6000 Series Pow...
# 8: Guess: $259.63 Truth: $289.00 Error: $29.37 SLE: 0.01 Item: Godox ML60Bi LED Light Kit, Handheld LED...
# 9: Guess: $302.41 Truth: $635.86 Error: $333.45 SLE: 0.55 Item: Randall RG75DG3PLUS G3 Plus 100-Watt Com...
# 10: Guess: $177.30 Truth: $65.99 Error: $111.31 SLE: 0.96 Item: HOLDWILL 6 Pack LED Shop Light, 4FT 24W ...
# 11: Guess: $256.95 Truth: $254.21 Error: $2.74 SLE: 0.00 Item: Viking Horns V103C/1005ATK 3 Gallon Air ...
# 123: Guess: $232.23 Truth: $196.99 Error: $35.24 SLE: 0.03 Item: Fitrite Autopart New Front Left Driver S...
# 124: Guess: $169.35 Truth: $46.55 Error: $122.80 SLE: 1.63 Item: Technical Precision Replacement for GE G...
# 125: Guess: $246.19 Truth: $356.99 Error: $110.80 SLE: 0.14 Item: Covercraft Carhartt SeatSaver Front Row ...
# 126: Guess: $208.54 Truth: $319.95 Error: $111.41 SLE: 0.18 Item: Sennheiser SD Pro 2 (506008) - Double-Si...
# 127: Guess: $206.43 Truth: $96.06 Error: $110.37 SLE: 0.58 Item: Hitachi MAF0110 Mass Air Flow Sensor
# 128: Guess: $276.90 Truth: $190.99 Error: $85.91 SLE: 0.14 Item: AmScope SE305R-P-LED-PS36A 10X-30X LED C...
# 129: Guess: $245.71 Truth: $257.95 Error: $12.24 SLE: 0.00 Item: Front Left Driver Side Window Regulator ...
# 130: Guess: $204.30 Truth: $62.95 Error: $141.35 SLE: 1.36 Item: Premium Replica Hubcap Set, Fits Nissan ...
# 131: Guess: $108.39 Truth: $47.66 Error: $60.73 SLE: 0.66 Item: Excellerations Phonics Spelling Game for...
# 132: Guess: $272.12 Truth: $226.99 Error: $45.13 SLE: 0.03 Item: RC4WD BigDog Dual Axle Scale Car/Truck T...
# 133: Guess: $249.29 Truth: $359.95 Error: $110.66 SLE: 0.13 Item: Unknown Stage 2 Clutch Kit - Low Altitud...
# 134: Guess: $238.84 Truth: $78.40 Error: $160.44 SLE: 1.22 Item: 2002-2008 Dodge Ram 1500 Mopar 4X4 Emble...
# 135: Guess: $255.64 Truth: $172.77 Error: $82.87 SLE: 0.15 Item: Pro Comp Alloys Series 89 Wheel with Pol...
# 136: Guess: $259.52 Truth: $316.45 Error: $56.93 SLE: 0.04 Item: Detroit Axle - Front Rear Strut & Coil S...
# 137: Guess: $203.54 Truth: $87.99 Error: $115.55 SLE: 0.69 Item: ECCPP Rear Wheel Axle Replacement fit fo...
# 138: Guess: $280.05 Truth: $226.63 Error: $53.42 SLE: 0.04 Item: Dell Latitude E6520 Intel i7-2720QM 2.20...
# 139: Guess: $256.69 Truth: $31.49 Error: $225.20 SLE: 4.29 Item: F FIERCE CYCLE 251pcs Black Universal Mo...
# 140: Guess: $169.65 Truth: $196.00 Error: $26.35 SLE: 0.02 Item: Flash Furniture 4 Pk. HERCULES Series 88...
# 141: Guess: $282.02 Truth: $78.40 Error: $203.62 SLE: 1.62 Item: B&M 30287 Throttle Valve/Kickdown Cable,...
# 142: Guess: $212.95 Truth: $116.25 Error: $96.70 SLE: 0.36 Item: Gates TCK226 PowerGrip Premium Timing Be...
# 143: Guess: $171.19 Truth: $112.78 Error: $58.41 SLE: 0.17 Item: Monroe Shocks & Struts Quick-Strut 17149...
# 144: Guess: $204.74 Truth: $27.32 Error: $177.42 SLE: 3.93 Item: Feit Electric BPMR16/GU10/930CA/6 35W EQ...
# 145: Guess: $187.52 Truth: $145.91 Error: $41.61 SLE: 0.06 Item: Yellow Jacket 2806 Contractor Extension ...
# 212: Guess: $203.93 Truth: $244.99 Error: $41.06 SLE: 0.03 Item: YU-GI-OH! Ignition Assault Booster Box
# 213: Guess: $169.62 Truth: $86.50 Error: $83.12 SLE: 0.45 Item: 48" x 36" Extra-Large Framed Magnetic Bl...
# 214: Guess: $329.81 Truth: $297.95 Error: $31.86 SLE: 0.01 Item: Dell Latitude D620 Renewed Notebook PC
# 215: Guess: $617.46 Truth: $399.99 Error: $217.47 SLE: 0.19 Item: acer Aspire 5 Laptop, AMD Ryzen 3 5300U ...
# 216: Guess: $239.39 Truth: $599.00 Error: $359.61 SLE: 0.84 Item: Elk 31080/6RC-GRN 30 by 6-Inch Viva 6-Li...
# 217: Guess: $273.31 Truth: $105.99 Error: $167.32 SLE: 0.89 Item: Barbie Top Model Doll
# 218: Guess: $307.55 Truth: $689.00 Error: $381.45 SLE: 0.65 Item: Danby Designer 20-In. Electric Range wit...
# 219: Guess: $239.85 Truth: $404.99 Error: $165.14 SLE: 0.27 Item: FixtureDisplays® Metal Truss Podium Doub...
# 220: Guess: $233.45 Truth: $207.76 Error: $25.69 SLE: 0.01 Item: ACDelco 13597235 GM Original Equipment A...
# 221: Guess: $225.33 Truth: $171.82 Error: $53.51 SLE: 0.07 Item: EBC S1KF1135 Stage-1 Premium Street Brak...
# 222: Guess: $261.31 Truth: $293.24 Error: $31.93 SLE: 0.01 Item: FXR Men's Boost FX Jacket (Black/Orange/...
# 223: Guess: $253.29 Truth: $374.95 Error: $121.66 SLE: 0.15 Item: SuperATV Scratch Resistant 3-in-1 Flip W...
# 224: Guess: $208.36 Truth: $111.99 Error: $96.37 SLE: 0.38 Item: SBU 3 Layer All Weather Mini Van Car Cov...
# 225: Guess: $118.64 Truth: $42.99 Error: $75.65 SLE: 1.00 Item: 2 Pack Outdoor Brochure Holder Advertisi...
# 226: Guess: $175.74 Truth: $116.71 Error: $59.03 SLE: 0.17 Item: Monroe Shocks & Struts Quick-Strut 17158...
# 227: Guess: $187.89 Truth: $118.61 Error: $69.28 SLE: 0.21 Item: Elements of Design Magellan EB235AL Thre...
# 228: Guess: $235.58 Truth: $147.12 Error: $88.46 SLE: 0.22 Item: GM Genuine Parts 15-62961 Air Conditioni...
# 229: Guess: $201.85 Truth: $119.99 Error: $81.86 SLE: 0.27 Item: Baseus 17-in-1 USB C Docking Station to ...
# 230: Guess: $161.36 Truth: $369.98 Error: $208.62 SLE: 0.68 Item: Whitehall™ Personalized Whitehall Capito...
# 231: Guess: $252.37 Truth: $315.55 Error: $63.18 SLE: 0.05 Item: Pro Circuit Works Pipe PY05250 for 02-19...
# 232: Guess: $306.77 Truth: $190.99 Error: $115.78 SLE: 0.22 Item: HYANKA 15 "1200W Professional DJ Speaker...
# 233: Guess: $237.25 Truth: $155.00 Error: $82.25 SLE: 0.18 Item: Bluetooth X6BT Card Reader Writer Encode...
# 234: Guess: $305.44 Truth: $349.99 Error: $44.55 SLE: 0.02 Item: AIRAID Cold Air Intake System by K&N: In...
# 235: Guess: $250.43 Truth: $249.99 Error: $0.44 SLE: 0.00 Item: Bostingner Shower Faucets Sets Complete,...
# 236: Guess: $229.01 Truth: $42.99 Error: $186.02 SLE: 2.74 Item: PIT66 Front Bumper Turn Signal Lights, C...
# 237: Guess: $51.55 Truth: $17.99 Error: $33.56 SLE: 1.04 Item: Caseology Bumpy Compatible with Google P...
# 238: Guess: $223.27 Truth: $425.00 Error: $201.73 SLE: 0.41 Item: Fleck 2510 Timer Mechanical Filter Contr...
# 239: Guess: $315.32 Truth: $249.99 Error: $65.33 SLE: 0.05 Item: Haloview MC7108 Wireless RV Backup Camer...
# 240: Guess: $196.94 Truth: $138.23 Error: $58.71 SLE: 0.12 Item: Schmidt Spiele - Manhattan
# 241: Guess: $269.53 Truth: $414.99 Error: $145.46 SLE: 0.19 Item: Corsa 14333 Tip Kit (Ford Mustang GT)
# 242: Guess: $203.78 Truth: $168.28 Error: $35.50 SLE: 0.04 Item: Hoshizaki FM116A Fan Motor Kit 1
# 243: Guess: $200.50 Truth: $199.99 Error: $0.51 SLE: 0.00 Item: BAINUO Antler Chandelier Lighting,6 Ligh...
# 244: Guess: $237.79 Truth: $126.70 Error: $111.09 SLE: 0.39 Item: DNA MOTORING HL-OH-FEXP06-SM-AM Smoke Le...
# 245: Guess: $209.68 Truth: $5.91 Error: $203.77 SLE: 11.68 Item: Wera Stainless 3840/1 TS 2.5mm Hex Inser...
# 246: Guess: $248.78 Truth: $193.06 Error: $55.72 SLE: 0.06 Item: Celestron - PowerSeeker 127EQ Telescope ...
# 247: Guess: $312.90 Truth: $249.99 Error: $62.91 SLE: 0.05 Item: NHOPEEW 10.1inch Android Car Radio Carpl...
# 248: Guess: $211.41 Truth: $64.12 Error: $147.29 SLE: 1.40 Item: Other Harmonica (Suzuki-2Timer24- A)
# 249: Guess: $255.84 Truth: $114.99 Error: $140.85 SLE: 0.63 Item: Harley Air Filter Venturi Intake Air Cle...
# 250: Guess: $364.10 Truth: $926.00 Error: $561.90 SLE: 0.87 Item: Elite Screens Edge Free Ambient Light Re...

# %%
specialists = []
frontiers = []
random_forests = []
prices = []
load_dotenv(override=True)
for item in tqdm(test[1000:1250]):
    text = description(item)
    specialists.append(specialist.price(text))
    frontiers.append(frontier.price(text))
    random_forests.append(random_forest.price(text))
    prices.append(item.price)
    time.sleep(4.5)
# Out:
#  40%|███████████████████████████████▌                                              | 101/250 [53:37<1:29:05, 35.88s/it]
# Error: 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. [violations {
#   quota_metric: "generativelanguage.googleapis.com/generate_content_free_tier_requests"
#   quota_id: "GenerateRequestsPerDayPerProjectPerModel-FreeTier"
#   quota_dimensions {
#     key: "model"
#     value: "gemini-2.5-pro"
#   }
#   quota_dimensions {
#     key: "location"
#     value: "global"
#   }
#   quota_value: 100
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 1
# }
# ]
# Error: 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. [violations {
#   quota_metric: "generativelanguage.googleapis.com/generate_content_free_tier_requests"
#   quota_id: "GenerateRequestsPerDayPerProjectPerModel-FreeTier"
#   quota_dimensions {
#     key: "model"
#     value: "gemini-2.5-pro"
#   }
#   quota_dimensions {
#     key: "location"
#     value: "global"
#   }
#   quota_value: 100
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 1
# }
# ]
# Error: 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. [violations {
#   quota_metric: "generativelanguage.googleapis.com/generate_content_free_tier_requests"
#   quota_id: "GenerateRequestsPerDayPerProjectPerModel-FreeTier"
#   quota_dimensions {
#     key: "model"
#     value: "gemini-2.5-pro"
#   }
#   quota_dimensions {
#     key: "location"
#     value: "global"
#   }
#   quota_value: 100
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 1
# }
# ]
# Error: 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. [violations {
#   quota_metric: "generativelanguage.googleapis.com/generate_content_free_tier_requests"
#   quota_id: "GenerateRequestsPerDayPerProjectPerModel-FreeTier"
#   quota_dimensions {
#     key: "model"
#     value: "gemini-2.5-pro"
#   }
#   quota_dimensions {
#     key: "location"
#     value: "global"
#   }
#   quota_value: 100
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 1
# }
# ]
# Error: 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. [violations {
#   quota_metric: "generativelanguage.googleapis.com/generate_content_free_tier_requests"
#   quota_id: "GenerateRequestsPerDayPerProjectPerModel-FreeTier"
#   quota_dimensions {
#     key: "model"
#     value: "gemini-2.5-pro"
#   }
#   quota_dimensions {
#     key: "location"
#     value: "global"
#   }
#   quota_value: 100
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 1
# }
# ]
# Error: 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. [violations {
#   quota_metric: "generativelanguage.googleapis.com/generate_content_free_tier_requests"
#   quota_id: "GenerateRequestsPerDayPerProjectPerModel-FreeTier"
#   quota_dimensions {
#     key: "model"
#     value: "gemini-2.5-pro"
#   }
#   quota_dimensions {
#     key: "location"
#     value: "global"
#   }
#   quota_value: 100
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
# }
# ]
# Error: 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. [violations {
#   quota_metric: "generativelanguage.googleapis.com/generate_content_free_tier_requests"
#   quota_id: "GenerateRequestsPerDayPerProjectPerModel-FreeTier"
#   quota_dimensions {
#     key: "model"
#     value: "gemini-2.5-pro"
#   }
#   quota_dimensions {
#     key: "location"
#     value: "global"
#   }
#   quota_value: 100
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
# }
# ]
# Error: 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. [violations {
#   quota_metric: "generativelanguage.googleapis.com/generate_content_free_tier_requests"
#   quota_id: "GenerateRequestsPerDayPerProjectPerModel-FreeTier"
#   quota_dimensions {
#     key: "model"
#     value: "gemini-2.5-pro"
#   }
#   quota_dimensions {
#     key: "location"
#     value: "global"
#   }
#   quota_value: 100
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
# }
# ]
#  41%|███████████████████████████████▊                                              | 102/250 [53:46<1:08:16, 27.68s/it]
# Error: 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. [violations {
#   quota_metric: "generativelanguage.googleapis.com/generate_content_free_tier_requests"
#   quota_id: "GenerateRequestsPerDayPerProjectPerModel-FreeTier"
#   quota_dimensions {
#     key: "model"
#     value: "gemini-2.5-pro"
#   }
#   quota_dimensions {
#     key: "location"
#     value: "global"
#   }
#   quota_value: 100
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 53
# }
# ]
# Error: 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. [violations {
#   quota_metric: "generativelanguage.googleapis.com/generate_content_free_tier_requests"
#   quota_id: "GenerateRequestsPerDayPerProjectPerModel-FreeTier"
#   quota_dimensions {
#     key: "model"
#     value: "gemini-2.5-pro"
#   }
#   quota_dimensions {
#     key: "location"
#     value: "global"
#   }
#   quota_value: 100
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 53
# }
# ]
# Error: 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. [violations {
#   quota_metric: "generativelanguage.googleapis.com/generate_content_free_tier_requests"
#   quota_id: "GenerateRequestsPerDayPerProjectPerModel-FreeTier"
#   quota_dimensions {
#     key: "model"
#     value: "gemini-2.5-pro"
#   }
#   quota_dimensions {
#     key: "location"
#     value: "global"
#   }
#   quota_value: 100
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 53
# }
# ]
# Error: 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. [violations {
#   quota_metric: "generativelanguage.googleapis.com/generate_content_free_tier_requests"
#   quota_id: "GenerateRequestsPerDayPerProjectPerModel-FreeTier"
#   quota_dimensions {
#     key: "model"
#     value: "gemini-2.5-pro"
#   }
#   quota_dimensions {
#     key: "location"
#     value: "global"
#   }
#   quota_value: 100
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 52
# }
# ]
# Error: 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. [violations {
#   quota_metric: "generativelanguage.googleapis.com/generate_content_free_tier_requests"
#   quota_id: "GenerateRequestsPerDayPerProjectPerModel-FreeTier"
#   quota_dimensions {
#     key: "model"
#     value: "gemini-2.5-pro"
#   }
#   quota_dimensions {
#     key: "location"
#     value: "global"
#   }
#   quota_value: 100
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 52
# }
# ]
# Error: 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. [violations {
#   quota_metric: "generativelanguage.googleapis.com/generate_content_free_tier_requests"
#   quota_id: "GenerateRequestsPerDayPerProjectPerModel-FreeTier"
#   quota_dimensions {
#     key: "model"
#     value: "gemini-2.5-pro"
#   }
#   quota_dimensions {
#     key: "location"
#     value: "global"
#   }
#   quota_value: 100
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 52
# }
# ]
# Error: 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. [violations {
#   quota_metric: "generativelanguage.googleapis.com/generate_content_free_tier_requests"
#   quota_id: "GenerateRequestsPerDayPerProjectPerModel-FreeTier"
#   quota_dimensions {
#     key: "model"
#     value: "gemini-2.5-pro"
#   }
#   quota_dimensions {
#     key: "location"
#     value: "global"
#   }
#   quota_value: 100
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 52
# }
# ]
# Error: 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. [violations {
#   quota_metric: "generativelanguage.googleapis.com/generate_content_free_tier_requests"
#   quota_id: "GenerateRequestsPerDayPerProjectPerModel-FreeTier"
#   quota_dimensions {
#     key: "model"
#     value: "gemini-2.5-pro"
#   }
#   quota_dimensions {
#     key: "location"
#     value: "global"
#   }
#   quota_value: 100
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 52
# }
# ]
#  41%|████████████████████████████████▉                                               | 103/250 [53:54<53:22, 21.79s/it]
# Error: 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. [violations {
#   quota_metric: "generativelanguage.googleapis.com/generate_content_free_tier_requests"
#   quota_id: "GenerateRequestsPerDayPerProjectPerModel-FreeTier"
#   quota_dimensions {
#     key: "model"
#     value: "gemini-2.5-pro"
#   }
#   quota_dimensions {
#     key: "location"
#     value: "global"
#   }
#   quota_value: 100
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 45
# }
# ]
# Error: 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. [violations {
#   quota_metric: "generativelanguage.googleapis.com/generate_content_free_tier_requests"
#   quota_id: "GenerateRequestsPerDayPerProjectPerModel-FreeTier"
#   quota_dimensions {
#     key: "model"
#     value: "gemini-2.5-pro"
#   }
#   quota_dimensions {
#     key: "location"
#     value: "global"
#   }
#   quota_value: 100
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 45
# }
# ]
# Error: 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. [violations {
#   quota_metric: "generativelanguage.googleapis.com/generate_content_free_tier_requests"
#   quota_id: "GenerateRequestsPerDayPerProjectPerModel-FreeTier"
#   quota_dimensions {
#     key: "model"
#     value: "gemini-2.5-pro"
#   }
#   quota_dimensions {
#     key: "location"
#     value: "global"
#   }
#   quota_value: 100
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 45
# }
# ]
# Error: 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. [violations {
#   quota_metric: "generativelanguage.googleapis.com/generate_content_free_tier_requests"
#   quota_id: "GenerateRequestsPerDayPerProjectPerModel-FreeTier"
#   quota_dimensions {
#     key: "model"
#     value: "gemini-2.5-pro"
#   }
#   quota_dimensions {
#     key: "location"
#     value: "global"
#   }
#   quota_value: 100
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 44
# }
# ]
# Error: 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. [violations {
#   quota_metric: "generativelanguage.googleapis.com/generate_content_free_tier_requests"
#   quota_id: "GenerateRequestsPerDayPerProjectPerModel-FreeTier"
#   quota_dimensions {
#     key: "model"
#     value: "gemini-2.5-pro"
#   }
#   quota_dimensions {
#     key: "location"
#     value: "global"
#   }
#   quota_value: 100
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 44
# }
# ]
# Error: 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. [violations {
#   quota_metric: "generativelanguage.googleapis.com/generate_content_free_tier_requests"
#   quota_id: "GenerateRequestsPerDayPerProjectPerModel-FreeTier"
#   quota_dimensions {
#     key: "model"
#     value: "gemini-2.5-pro"
#   }
#   quota_dimensions {
#     key: "location"
#     value: "global"
#   }
#   quota_value: 100
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 44
# }
# ]
# Error: 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. [violations {
#   quota_metric: "generativelanguage.googleapis.com/generate_content_free_tier_requests"
#   quota_id: "GenerateRequestsPerDayPerProjectPerModel-FreeTier"
#   quota_dimensions {
#     key: "model"
#     value: "gemini-2.5-pro"
#   }
#   quota_dimensions {
#     key: "location"
#     value: "global"
#   }
#   quota_value: 100
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 44
# }
# ]
# Error: 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. [violations {
#   quota_metric: "generativelanguage.googleapis.com/generate_content_free_tier_requests"
#   quota_id: "GenerateRequestsPerDayPerProjectPerModel-FreeTier"
#   quota_dimensions {
#     key: "model"
#     value: "gemini-2.5-pro"
#   }
#   quota_dimensions {
#     key: "location"
#     value: "global"
#   }
#   quota_value: 100
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 44
# }
# ]
#  42%|█████████████████████████████████▎                                              | 104/250 [54:02<43:00, 17.67s/it]
# Error: 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. [violations {
#   quota_metric: "generativelanguage.googleapis.com/generate_content_free_tier_requests"
#   quota_id: "GenerateRequestsPerDayPerProjectPerModel-FreeTier"
#   quota_dimensions {
#     key: "model"
#     value: "gemini-2.5-pro"
#   }
#   quota_dimensions {
#     key: "location"
#     value: "global"
#   }
#   quota_value: 100
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 37
# }
# ]
# Error: 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. [violations {
#   quota_metric: "generativelanguage.googleapis.com/generate_content_free_tier_requests"
#   quota_id: "GenerateRequestsPerDayPerProjectPerModel-FreeTier"
#   quota_dimensions {
#     key: "model"
#     value: "gemini-2.5-pro"
#   }
#   quota_dimensions {
#     key: "location"
#     value: "global"
#   }
#   quota_value: 100
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 37
# }
# ]
# Error: 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. [violations {
#   quota_metric: "generativelanguage.googleapis.com/generate_content_free_tier_requests"
#   quota_id: "GenerateRequestsPerDayPerProjectPerModel-FreeTier"
#   quota_dimensions {
#     key: "model"
#     value: "gemini-2.5-pro"
#   }
#   quota_dimensions {
#     key: "location"
#     value: "global"
#   }
#   quota_value: 100
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 37
# }
# ]
# Error: 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. [violations {
#   quota_metric: "generativelanguage.googleapis.com/generate_content_free_tier_requests"
#   quota_id: "GenerateRequestsPerDayPerProjectPerModel-FreeTier"
#   quota_dimensions {
#     key: "model"
#     value: "gemini-2.5-pro"
#   }
#   quota_dimensions {
#     key: "location"
#     value: "global"
#   }
#   quota_value: 100
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 36
# }
# ]
# Error: 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. [violations {
#   quota_metric: "generativelanguage.googleapis.com/generate_content_free_tier_requests"
#   quota_id: "GenerateRequestsPerDayPerProjectPerModel-FreeTier"
#   quota_dimensions {
#     key: "model"
#     value: "gemini-2.5-pro"
#   }
#   quota_dimensions {
#     key: "location"
#     value: "global"
#   }
#   quota_value: 100
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 36
# }
# ]
# Error: 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. [violations {
#   quota_metric: "generativelanguage.googleapis.com/generate_content_free_tier_requests"
#   quota_id: "GenerateRequestsPerDayPerProjectPerModel-FreeTier"
#   quota_dimensions {
#     key: "model"
#     value: "gemini-2.5-pro"
#   }
#   quota_dimensions {
#     key: "location"
#     value: "global"
#   }
#   quota_value: 100
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 36
# }
# ]
# Error: 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. [violations {
#   quota_metric: "generativelanguage.googleapis.com/generate_content_free_tier_requests"
#   quota_id: "GenerateRequestsPerDayPerProjectPerModel-FreeTier"
#   quota_dimensions {
#     key: "model"
#     value: "gemini-2.5-pro"
#   }
#   quota_dimensions {
#     key: "location"
#     value: "global"
#   }
#   quota_value: 100
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 36
# }
# ]
# Error: 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. [violations {
#   quota_metric: "generativelanguage.googleapis.com/generate_content_free_tier_requests"
#   quota_id: "GenerateRequestsPerDayPerProjectPerModel-FreeTier"
#   quota_dimensions {
#     key: "model"
#     value: "gemini-2.5-pro"
#   }
#   quota_dimensions {
#     key: "location"
#     value: "global"
#   }
#   quota_value: 100
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 36
# }
# ]
#  42%|█████████████████████████████████▌                                              | 105/250 [54:10<35:38, 14.75s/it]
# Error: 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. [violations {
#   quota_metric: "generativelanguage.googleapis.com/generate_content_free_tier_requests"
#   quota_id: "GenerateRequestsPerDayPerProjectPerModel-FreeTier"
#   quota_dimensions {
#     key: "model"
#     value: "gemini-2.5-pro"
#   }
#   quota_dimensions {
#     key: "location"
#     value: "global"
#   }
#   quota_value: 100
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 29
# }
# ]
# Error: 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. [violations {
#   quota_metric: "generativelanguage.googleapis.com/generate_content_free_tier_requests"
#   quota_id: "GenerateRequestsPerDayPerProjectPerModel-FreeTier"
#   quota_dimensions {
#     key: "model"
#     value: "gemini-2.5-pro"
#   }
#   quota_dimensions {
#     key: "location"
#     value: "global"
#   }
#   quota_value: 100
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 29
# }
# ]
# Error: 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. [violations {
#   quota_metric: "generativelanguage.googleapis.com/generate_content_free_tier_requests"
#   quota_id: "GenerateRequestsPerDayPerProjectPerModel-FreeTier"
#   quota_dimensions {
#     key: "model"
#     value: "gemini-2.5-pro"
#   }
#   quota_dimensions {
#     key: "location"
#     value: "global"
#   }
#   quota_value: 100
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 29
# }
# ]
# Error: 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. [violations {
#   quota_metric: "generativelanguage.googleapis.com/generate_content_free_tier_requests"
#   quota_id: "GenerateRequestsPerDayPerProjectPerModel-FreeTier"
#   quota_dimensions {
#     key: "model"
#     value: "gemini-2.5-pro"
#   }
#   quota_dimensions {
#     key: "location"
#     value: "global"
#   }
#   quota_value: 100
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 28
# }
# ]
# Error: 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. [violations {
#   quota_metric: "generativelanguage.googleapis.com/generate_content_free_tier_requests"
#   quota_id: "GenerateRequestsPerDayPerProjectPerModel-FreeTier"
#   quota_dimensions {
#     key: "model"
#     value: "gemini-2.5-pro"
#   }
#   quota_dimensions {
#     key: "location"
#     value: "global"
#   }
#   quota_value: 100
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 28
# }
# ]
# Error: 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. [violations {
#   quota_metric: "generativelanguage.googleapis.com/generate_content_free_tier_requests"
#   quota_id: "GenerateRequestsPerDayPerProjectPerModel-FreeTier"
#   quota_dimensions {
#     key: "model"
#     value: "gemini-2.5-pro"
#   }
#   quota_dimensions {
#     key: "location"
#     value: "global"
#   }
#   quota_value: 100
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 28
# }
# ]
# Error: 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. [violations {
#   quota_metric: "generativelanguage.googleapis.com/generate_content_free_tier_requests"
#   quota_id: "GenerateRequestsPerDayPerProjectPerModel-FreeTier"
#   quota_dimensions {
#     key: "model"
#     value: "gemini-2.5-pro"
#   }
#   quota_dimensions {
#     key: "location"
#     value: "global"
#   }
#   quota_value: 100
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 28
# }
# ]
# Error: 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. [violations {
#   quota_metric: "generativelanguage.googleapis.com/generate_content_free_tier_requests"
#   quota_id: "GenerateRequestsPerDayPerProjectPerModel-FreeTier"
#   quota_dimensions {
#     key: "model"
#     value: "gemini-2.5-pro"
#   }
#   quota_dimensions {
#     key: "location"
#     value: "global"
#   }
#   quota_value: 100
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 28
# }
# ]
#  42%|█████████████████████████████████▉                                              | 106/250 [54:18<30:37, 12.76s/it]
# Error: 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. [violations {
#   quota_metric: "generativelanguage.googleapis.com/generate_content_free_tier_requests"
#   quota_id: "GenerateRequestsPerDayPerProjectPerModel-FreeTier"
#   quota_dimensions {
#     key: "model"
#     value: "gemini-2.5-pro"
#   }
#   quota_dimensions {
#     key: "location"
#     value: "global"
#   }
#   quota_value: 100
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 21
# }
# ]
# Error: 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. [violations {
#   quota_metric: "generativelanguage.googleapis.com/generate_content_free_tier_requests"
#   quota_id: "GenerateRequestsPerDayPerProjectPerModel-FreeTier"
#   quota_dimensions {
#     key: "model"
#     value: "gemini-2.5-pro"
#   }
#   quota_dimensions {
#     key: "location"
#     value: "global"
#   }
#   quota_value: 100
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 21
# }
# ]
# Error: 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. [violations {
#   quota_metric: "generativelanguage.googleapis.com/generate_content_free_tier_requests"
#   quota_id: "GenerateRequestsPerDayPerProjectPerModel-FreeTier"
#   quota_dimensions {
#     key: "model"
#     value: "gemini-2.5-pro"
#   }
#   quota_dimensions {
#     key: "location"
#     value: "global"
#   }
#   quota_value: 100
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 20
# }
# ]
# Error: 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. [violations {
#   quota_metric: "generativelanguage.googleapis.com/generate_content_free_tier_requests"
#   quota_id: "GenerateRequestsPerDayPerProjectPerModel-FreeTier"
#   quota_dimensions {
#     key: "model"
#     value: "gemini-2.5-pro"
#   }
#   quota_dimensions {
#     key: "location"
#     value: "global"
#   }
#   quota_value: 100
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 20
# }
# ]
# Error: 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. [violations {
#   quota_metric: "generativelanguage.googleapis.com/generate_content_free_tier_requests"
#   quota_id: "GenerateRequestsPerDayPerProjectPerModel-FreeTier"
#   quota_dimensions {
#     key: "model"
#     value: "gemini-2.5-pro"
#   }
#   quota_dimensions {
#     key: "location"
#     value: "global"
#   }
#   quota_value: 100
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 20
# }
# ]
# Error: 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. [violations {
#   quota_metric: "generativelanguage.googleapis.com/generate_content_free_tier_requests"
#   quota_id: "GenerateRequestsPerDayPerProjectPerModel-FreeTier"
#   quota_dimensions {
#     key: "model"
#     value: "gemini-2.5-pro"
#   }
#   quota_dimensions {
#     key: "location"
#     value: "global"
#   }
#   quota_value: 100
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 20
# }
# ]
# Error: 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. [violations {
#   quota_metric: "generativelanguage.googleapis.com/generate_content_free_tier_requests"
#   quota_id: "GenerateRequestsPerDayPerProjectPerModel-FreeTier"
#   quota_dimensions {
#     key: "model"
#     value: "gemini-2.5-pro"
#   }
#   quota_dimensions {
#     key: "location"
#     value: "global"
#   }
#   quota_value: 100
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 20
# }
# ]
# Error: 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. [violations {
#   quota_metric: "generativelanguage.googleapis.com/generate_content_free_tier_requests"
#   quota_id: "GenerateRequestsPerDayPerProjectPerModel-FreeTier"
#   quota_dimensions {
#     key: "model"
#     value: "gemini-2.5-pro"
#   }
#   quota_dimensions {
#     key: "location"
#     value: "global"
#   }
#   quota_value: 100
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 20
# }
# ]
#  43%|██████████████████████████████████▏                                             | 107/250 [54:26<27:01, 11.34s/it]
# Error: 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. [violations {
#   quota_metric: "generativelanguage.googleapis.com/generate_content_free_tier_requests"
#   quota_id: "GenerateRequestsPerDayPerProjectPerModel-FreeTier"
#   quota_dimensions {
#     key: "model"
#     value: "gemini-2.5-pro"
#   }
#   quota_dimensions {
#     key: "location"
#     value: "global"
#   }
#   quota_value: 100
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 13
# }
# ]
# Error: 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. [violations {
#   quota_metric: "generativelanguage.googleapis.com/generate_content_free_tier_requests"
#   quota_id: "GenerateRequestsPerDayPerProjectPerModel-FreeTier"
#   quota_dimensions {
#     key: "model"
#     value: "gemini-2.5-pro"
#   }
#   quota_dimensions {
#     key: "location"
#     value: "global"
#   }
#   quota_value: 100
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 13
# }
# ]
# Error: 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. [violations {
#   quota_metric: "generativelanguage.googleapis.com/generate_content_free_tier_requests"
#   quota_id: "GenerateRequestsPerDayPerProjectPerModel-FreeTier"
#   quota_dimensions {
#     key: "model"
#     value: "gemini-2.5-pro"
#   }
#   quota_dimensions {
#     key: "location"
#     value: "global"
#   }
#   quota_value: 100
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 12
# }
# ]
# Error: 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. [violations {
#   quota_metric: "generativelanguage.googleapis.com/generate_content_free_tier_requests"
#   quota_id: "GenerateRequestsPerDayPerProjectPerModel-FreeTier"
#   quota_dimensions {
#     key: "model"
#     value: "gemini-2.5-pro"
#   }
#   quota_dimensions {
#     key: "location"
#     value: "global"
#   }
#   quota_value: 100
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 12
# }
# ]
# Error: 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. [violations {
#   quota_metric: "generativelanguage.googleapis.com/generate_content_free_tier_requests"
#   quota_id: "GenerateRequestsPerDayPerProjectPerModel-FreeTier"
#   quota_dimensions {
#     key: "model"
#     value: "gemini-2.5-pro"
#   }
#   quota_dimensions {
#     key: "location"
#     value: "global"
#   }
#   quota_value: 100
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 12
# }
# ]
# Error: 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. [violations {
#   quota_metric: "generativelanguage.googleapis.com/generate_content_free_tier_requests"
#   quota_id: "GenerateRequestsPerDayPerProjectPerModel-FreeTier"
#   quota_dimensions {
#     key: "model"
#     value: "gemini-2.5-pro"
#   }
#   quota_dimensions {
#     key: "location"
#     value: "global"
#   }
#   quota_value: 100
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 12
# }
# ]
# Error: 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. [violations {
#   quota_metric: "generativelanguage.googleapis.com/generate_content_free_tier_requests"
#   quota_id: "GenerateRequestsPerDayPerProjectPerModel-FreeTier"
#   quota_dimensions {
#     key: "model"
#     value: "gemini-2.5-pro"
#   }
#   quota_dimensions {
#     key: "location"
#     value: "global"
#   }
#   quota_value: 100
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 12
# }
# ]
# Error: 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. [violations {
#   quota_metric: "generativelanguage.googleapis.com/generate_content_free_tier_requests"
#   quota_id: "GenerateRequestsPerDayPerProjectPerModel-FreeTier"
#   quota_dimensions {
#     key: "model"
#     value: "gemini-2.5-pro"
#   }
#   quota_dimensions {
#     key: "location"
#     value: "global"
#   }
#   quota_value: 100
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 11
# }
# ]
#  43%|██████████████████████████████████▌                                             | 108/250 [54:35<24:47, 10.48s/it]
# Error: 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. [violations {
#   quota_metric: "generativelanguage.googleapis.com/generate_content_free_tier_requests"
#   quota_id: "GenerateRequestsPerDayPerProjectPerModel-FreeTier"
#   quota_dimensions {
#     key: "model"
#     value: "gemini-2.5-pro"
#   }
#   quota_dimensions {
#     key: "location"
#     value: "global"
#   }
#   quota_value: 100
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 4
# }
# ]
# Error: 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. [violations {
#   quota_metric: "generativelanguage.googleapis.com/generate_content_free_tier_requests"
#   quota_id: "GenerateRequestsPerDayPerProjectPerModel-FreeTier"
#   quota_dimensions {
#     key: "model"
#     value: "gemini-2.5-pro"
#   }
#   quota_dimensions {
#     key: "location"
#     value: "global"
#   }
#   quota_value: 100
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 4
# }
# ]
# Error: 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. [violations {
#   quota_metric: "generativelanguage.googleapis.com/generate_content_free_tier_requests"
#   quota_id: "GenerateRequestsPerDayPerProjectPerModel-FreeTier"
#   quota_dimensions {
#     key: "model"
#     value: "gemini-2.5-pro"
#   }
#   quota_dimensions {
#     key: "location"
#     value: "global"
#   }
#   quota_value: 100
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 4
# }
# ]
# Error: 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. [violations {
#   quota_metric: "generativelanguage.googleapis.com/generate_content_free_tier_requests"
#   quota_id: "GenerateRequestsPerDayPerProjectPerModel-FreeTier"
#   quota_dimensions {
#     key: "model"
#     value: "gemini-2.5-pro"
#   }
#   quota_dimensions {
#     key: "location"
#     value: "global"
#   }
#   quota_value: 100
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 4
# }
# ]
# Error: 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. [violations {
#   quota_metric: "generativelanguage.googleapis.com/generate_content_free_tier_requests"
#   quota_id: "GenerateRequestsPerDayPerProjectPerModel-FreeTier"
#   quota_dimensions {
#     key: "model"
#     value: "gemini-2.5-pro"
#   }
#   quota_dimensions {
#     key: "location"
#     value: "global"
#   }
#   quota_value: 100
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 4
# }
# ]
# Error: 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. [violations {
#   quota_metric: "generativelanguage.googleapis.com/generate_content_free_tier_requests"
#   quota_id: "GenerateRequestsPerDayPerProjectPerModel-FreeTier"
#   quota_dimensions {
#     key: "model"
#     value: "gemini-2.5-pro"
#   }
#   quota_dimensions {
#     key: "location"
#     value: "global"
#   }
#   quota_value: 100
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 4
# }
# ]
# Error: 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. [violations {
#   quota_metric: "generativelanguage.googleapis.com/generate_content_free_tier_requests"
#   quota_id: "GenerateRequestsPerDayPerProjectPerModel-FreeTier"
#   quota_dimensions {
#     key: "model"
#     value: "gemini-2.5-pro"
#   }
#   quota_dimensions {
#     key: "location"
#     value: "global"
#   }
#   quota_value: 100
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 3
# }
# ]
# Error: 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. [violations {
#   quota_metric: "generativelanguage.googleapis.com/generate_content_free_tier_requests"
#   quota_id: "GenerateRequestsPerDayPerProjectPerModel-FreeTier"
#   quota_dimensions {
#     key: "model"
#     value: "gemini-2.5-pro"
#   }
#   quota_dimensions {
#     key: "location"
#     value: "global"
#   }
#   quota_value: 100
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 3
# }
# ]
#  44%|██████████████████████████████████▉                                             | 109/250 [54:43<22:59,  9.79s/it]
# Error: 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. [violations {
#   quota_metric: "generativelanguage.googleapis.com/generate_content_free_tier_requests"
#   quota_id: "GenerateRequestsPerDayPerProjectPerModel-FreeTier"
#   quota_dimensions {
#     key: "model"
#     value: "gemini-2.5-pro"
#   }
#   quota_dimensions {
#     key: "location"
#     value: "global"
#   }
#   quota_value: 100
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 56
# }
# ]
# Error: 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. [violations {
#   quota_metric: "generativelanguage.googleapis.com/generate_content_free_tier_requests"
#   quota_id: "GenerateRequestsPerDayPerProjectPerModel-FreeTier"
#   quota_dimensions {
#     key: "model"
#     value: "gemini-2.5-pro"
#   }
#   quota_dimensions {
#     key: "location"
#     value: "global"
#   }
#   quota_value: 100
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 56
# }
# ]
# Error: 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. [violations {
#   quota_metric: "generativelanguage.googleapis.com/generate_content_free_tier_requests"
#   quota_id: "GenerateRequestsPerDayPerProjectPerModel-FreeTier"
#   quota_dimensions {
#     key: "model"
#     value: "gemini-2.5-pro"
#   }
#   quota_dimensions {
#     key: "location"
#     value: "global"
#   }
#   quota_value: 100
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 56
# }
# ]
# Error: 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. [violations {
#   quota_metric: "generativelanguage.googleapis.com/generate_content_free_tier_requests"
#   quota_id: "GenerateRequestsPerDayPerProjectPerModel-FreeTier"
#   quota_dimensions {
#     key: "model"
#     value: "gemini-2.5-pro"
#   }
#   quota_dimensions {
#     key: "location"
#     value: "global"
#   }
#   quota_value: 100
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 56
# }
# ]
# Error: 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. [violations {
#   quota_metric: "generativelanguage.googleapis.com/generate_content_free_tier_requests"
#   quota_id: "GenerateRequestsPerDayPerProjectPerModel-FreeTier"
#   quota_dimensions {
#     key: "model"
#     value: "gemini-2.5-pro"
#   }
#   quota_dimensions {
#     key: "location"
#     value: "global"
#   }
#   quota_value: 100
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 56
# }
# ]
# Error: 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. [violations {
#   quota_metric: "generativelanguage.googleapis.com/generate_content_free_tier_requests"
#   quota_id: "GenerateRequestsPerDayPerProjectPerModel-FreeTier"
#   quota_dimensions {
#     key: "model"
#     value: "gemini-2.5-pro"
#   }
#   quota_dimensions {
#     key: "location"
#     value: "global"
#   }
#   quota_value: 100
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 55
# }
# ]
# Error: 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. [violations {
#   quota_metric: "generativelanguage.googleapis.com/generate_content_free_tier_requests"
#   quota_id: "GenerateRequestsPerDayPerProjectPerModel-FreeTier"
#   quota_dimensions {
#     key: "model"
#     value: "gemini-2.5-pro"
#   }
#   quota_dimensions {
#     key: "location"
#     value: "global"
#   }
#   quota_value: 100
# }
# , links {
# ...
# }
# , retry_delay {
#   seconds: 3
# }
# ]
# Error: 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. [violations {
#   quota_metric: "generativelanguage.googleapis.com/generate_content_free_tier_requests"
#   quota_id: "GenerateRequestsPerDayPerProjectPerModel-FreeTier"
#   quota_dimensions {
#     key: "model"
#     value: "gemini-2.5-pro"
#   }
#   quota_dimensions {
#     key: "location"
#     value: "global"
#   }
#   quota_value: 100
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 3
# }
# ]
# Error: 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. [violations {
#   quota_metric: "generativelanguage.googleapis.com/generate_content_free_tier_requests"
#   quota_id: "GenerateRequestsPerDayPerProjectPerModel-FreeTier"
#   quota_dimensions {
#     key: "model"
#     value: "gemini-2.5-pro"
#   }
#   quota_dimensions {
#     key: "location"
#     value: "global"
#   }
#   quota_value: 100
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 3
# }
# ]
# Error: 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. [violations {
#   quota_metric: "generativelanguage.googleapis.com/generate_content_free_tier_requests"
#   quota_id: "GenerateRequestsPerDayPerProjectPerModel-FreeTier"
#   quota_dimensions {
#     key: "model"
#     value: "gemini-2.5-pro"
#   }
#   quota_dimensions {
#     key: "location"
#     value: "global"
#   }
#   quota_value: 100
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 3
# }
# ]
# Error: 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. [violations {
#   quota_metric: "generativelanguage.googleapis.com/generate_content_free_tier_requests"
#   quota_id: "GenerateRequestsPerDayPerProjectPerModel-FreeTier"
#   quota_dimensions {
#     key: "model"
#     value: "gemini-2.5-pro"
#   }
#   quota_dimensions {
#     key: "location"
#     value: "global"
#   }
#   quota_value: 100
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 3
# }
# ]
# Error: 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. [violations {
#   quota_metric: "generativelanguage.googleapis.com/generate_content_free_tier_requests"
#   quota_id: "GenerateRequestsPerDayPerProjectPerModel-FreeTier"
#   quota_dimensions {
#     key: "model"
#     value: "gemini-2.5-pro"
#   }
#   quota_dimensions {
#     key: "location"
#     value: "global"
#   }
#   quota_value: 100
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 2
# }
# ]
# Error: 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. [violations {
#   quota_metric: "generativelanguage.googleapis.com/generate_content_free_tier_requests"
#   quota_id: "GenerateRequestsPerDayPerProjectPerModel-FreeTier"
#   quota_dimensions {
#     key: "model"
#     value: "gemini-2.5-pro"
#   }
#   quota_dimensions {
#     key: "location"
#     value: "global"
#   }
#   quota_value: 100
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 2
# }
# ]
# Error: 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. [violations {
#   quota_metric: "generativelanguage.googleapis.com/generate_content_free_tier_requests"
#   quota_id: "GenerateRequestsPerDayPerProjectPerModel-FreeTier"
#   quota_dimensions {
#     key: "model"
#     value: "gemini-2.5-pro"
#   }
#   quota_dimensions {
#     key: "location"
#     value: "global"
#   }
#   quota_value: 100
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 2
# }
# ]
#  86%|██████████████████████████████████████████████████████████████████▊           | 214/250 [1:08:44<04:57,  8.28s/it]
# Error: 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. [violations {
#   quota_metric: "generativelanguage.googleapis.com/generate_content_free_tier_requests"
#   quota_id: "GenerateRequestsPerDayPerProjectPerModel-FreeTier"
#   quota_dimensions {
#     key: "model"
#     value: "gemini-2.5-pro"
#   }
#   quota_dimensions {
#     key: "location"
#     value: "global"
#   }
#   quota_value: 100
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 55
# }
# ]
# Error: 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. [violations {
#   quota_metric: "generativelanguage.googleapis.com/generate_content_free_tier_requests"
#   quota_id: "GenerateRequestsPerDayPerProjectPerModel-FreeTier"
#   quota_dimensions {
#     key: "model"
#     value: "gemini-2.5-pro"
#   }
#   quota_dimensions {
#     key: "location"
#     value: "global"
#   }
#   quota_value: 100
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 55
# }
# ]
# Error: 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. [violations {
#   quota_metric: "generativelanguage.googleapis.com/generate_content_free_tier_requests"
#   quota_id: "GenerateRequestsPerDayPerProjectPerModel-FreeTier"
#   quota_dimensions {
#     key: "model"
#     value: "gemini-2.5-pro"
#   }
#   quota_dimensions {
#     key: "location"
#     value: "global"
#   }
#   quota_value: 100
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 55
# }
# ]
# Error: 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. [violations {
#   quota_metric: "generativelanguage.googleapis.com/generate_content_free_tier_requests"
#   quota_id: "GenerateRequestsPerDayPerProjectPerModel-FreeTier"
#   quota_dimensions {
#     key: "model"
#     value: "gemini-2.5-pro"
#   }
#   quota_dimensions {
#     key: "location"
#     value: "global"
#   }
#   quota_value: 100
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 55
# }
# ]
# Error: 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. [violations {
#   quota_metric: "generativelanguage.googleapis.com/generate_content_free_tier_requests"
#   quota_id: "GenerateRequestsPerDayPerProjectPerModel-FreeTier"
#   quota_dimensions {
#     key: "model"
#     value: "gemini-2.5-pro"
#   }
#   quota_dimensions {
#     key: "location"
#     value: "global"
#   }
#   quota_value: 100
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 55
# }
# ]
# Error: 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. [violations {
#   quota_metric: "generativelanguage.googleapis.com/generate_content_free_tier_requests"
#   quota_id: "GenerateRequestsPerDayPerProjectPerModel-FreeTier"
#   quota_dimensions {
#     key: "model"
#     value: "gemini-2.5-pro"
#   }
#   quota_dimensions {
#     key: "location"
#     value: "global"
#   }
#   quota_value: 100
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 55
# }
# ]
# Error: 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. [violations {
#   quota_metric: "generativelanguage.googleapis.com/generate_content_free_tier_requests"
#   quota_id: "GenerateRequestsPerDayPerProjectPerModel-FreeTier"
#   quota_dimensions {
#     key: "model"
#     value: "gemini-2.5-pro"
#   }
#   quota_dimensions {
#     key: "location"
#     value: "global"
#   }
#   quota_value: 100
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 55
# }
# ]
# Error: 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. [violations {
#   quota_metric: "generativelanguage.googleapis.com/generate_content_free_tier_requests"
#   quota_id: "GenerateRequestsPerDayPerProjectPerModel-FreeTier"
#   quota_dimensions {
#     key: "model"
#     value: "gemini-2.5-pro"
#   }
#   quota_dimensions {
#     key: "location"
#     value: "global"
#   }
#   quota_value: 100
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 54
# }
# ]
#  86%|███████████████████████████████████████████████████████████████████           | 215/250 [1:08:51<04:44,  8.12s/it]
# Error: 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. [violations {
#   quota_metric: "generativelanguage.googleapis.com/generate_content_free_tier_requests"
#   quota_id: "GenerateRequestsPerDayPerProjectPerModel-FreeTier"
#   quota_dimensions {
#     key: "model"
#     value: "gemini-2.5-pro"
#   }
#   quota_dimensions {
#     key: "location"
#     value: "global"
#   }
#   quota_value: 100
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 47
# }
# ]
# Error: 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. [violations {
#   quota_metric: "generativelanguage.googleapis.com/generate_content_free_tier_requests"
#   quota_id: "GenerateRequestsPerDayPerProjectPerModel-FreeTier"
#   quota_dimensions {
#     key: "model"
#     value: "gemini-2.5-pro"
#   }
#   quota_dimensions {
#     key: "location"
#     value: "global"
#   }
#   quota_value: 100
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 47
# }
# ]
# Error: 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. [violations {
#   quota_metric: "generativelanguage.googleapis.com/generate_content_free_tier_requests"
#   quota_id: "GenerateRequestsPerDayPerProjectPerModel-FreeTier"
#   quota_dimensions {
#     key: "model"
#     value: "gemini-2.5-pro"
#   }
#   quota_dimensions {
#     key: "location"
#     value: "global"
#   }
#   quota_value: 100
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 47
# }
# ]
# Error: 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. [violations {
#   quota_metric: "generativelanguage.googleapis.com/generate_content_free_tier_requests"
#   quota_id: "GenerateRequestsPerDayPerProjectPerModel-FreeTier"
#   quota_dimensions {
#     key: "model"
#     value: "gemini-2.5-pro"
#   }
#   quota_dimensions {
#     key: "location"
#     value: "global"
#   }
#   quota_value: 100
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 47
# }
# ]
# Error: 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. [violations {
#   quota_metric: "generativelanguage.googleapis.com/generate_content_free_tier_requests"
#   quota_id: "GenerateRequestsPerDayPerProjectPerModel-FreeTier"
#   quota_dimensions {
#     key: "model"
#     value: "gemini-2.5-pro"
#   }
#   quota_dimensions {
#     key: "location"
#     value: "global"
#   }
#   quota_value: 100
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 47
# }
# ]
# Error: 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. [violations {
#   quota_metric: "generativelanguage.googleapis.com/generate_content_free_tier_requests"
#   quota_id: "GenerateRequestsPerDayPerProjectPerModel-FreeTier"
#   quota_dimensions {
#     key: "model"
#     value: "gemini-2.5-pro"
#   }
#   quota_dimensions {
#     key: "location"
#     value: "global"
#   }
#   quota_value: 100
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 47
# }
# ]
# Error: 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. [violations {
#   quota_metric: "generativelanguage.googleapis.com/generate_content_free_tier_requests"
#   quota_id: "GenerateRequestsPerDayPerProjectPerModel-FreeTier"
#   quota_dimensions {
#     key: "model"
#     value: "gemini-2.5-pro"
#   }
#   quota_dimensions {
#     key: "location"
#     value: "global"
#   }
#   quota_value: 100
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 47
# }
# ]
# Error: 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. [violations {
#   quota_metric: "generativelanguage.googleapis.com/generate_content_free_tier_requests"
#   quota_id: "GenerateRequestsPerDayPerProjectPerModel-FreeTier"
#   quota_dimensions {
#     key: "model"
#     value: "gemini-2.5-pro"
#   }
#   quota_dimensions {
#     key: "location"
#     value: "global"
#   }
#   quota_value: 100
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 46
# }
# ]
#  86%|███████████████████████████████████████████████████████████████████           | 215/250 [1:09:00<11:13, 19.26s/it]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[108], line 12
#      10 random_forests.append(random_forest.price(text))
#      11 prices.append(item.price)
# ---> 12 time.sleep(4.5)
#
# KeyboardInterrupt:

# %%
mins = [min(s,f,r) for s,f,r in zip(specialists, frontiers, random_forests)]
maxes = [max(s,f,r) for s,f,r in zip(specialists, frontiers, random_forests)]

X = pd.DataFrame({
    'Specialist': specialists,
    'Frontier': frontiers,
    'RandomForest': random_forests,
    'Min': mins,
    'Max': maxes,
})

# Convert y to a Series
y = pd.Series(prices)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[109], line 1
# ----> 1 mins = [min(s,f,r) for s,f,r in zip(specialists, frontiers, random_forests)]
#       2 maxes = [max(s,f,r) for s,f,r in zip(specialists, frontiers, random_forests)]
#       4 X = pd.DataFrame({
#       5     'Specialist': specialists,
#       6     'Frontier': frontiers,
#    (...)      9     'Max': maxes,
#      10 })
#
# Cell In[109], line 1, in <listcomp>(.0)
# ----> 1 mins = [min(s,f,r) for s,f,r in zip(specialists, frontiers, random_forests)]
#       2 maxes = [max(s,f,r) for s,f,r in zip(specialists, frontiers, random_forests)]
#       4 X = pd.DataFrame({
#       5     'Specialist': specialists,
#       6     'Frontier': frontiers,
#    (...)      9     'Max': maxes,
#      10 })
#
# TypeError: '<' not supported between instances of 'str' and 'float'

# %%
# Train a Linear Regression
np.random.seed(42)

lr = LinearRegression()
lr.fit(X, y)

feature_columns = X.columns.tolist()

for feature, coef in zip(feature_columns, lr.coef_):
    print(f"{feature}: {coef:.2f}")
print(f"Intercept={lr.intercept_:.2f}")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[110], line 5
#       2 np.random.seed(42)
#       4 lr = LinearRegression()
# ----> 5 lr.fit(X, y)
#       7 feature_columns = X.columns.tolist()
#       9 for feature, coef in zip(feature_columns, lr.coef_):
#
# NameError: name 'X' is not defined

# %%
joblib.dump(lr, 'ensemble_model.pkl')

# %%
from agents.ensemble_agent import EnsembleAgent
ensemble = EnsembleAgent(collection)

# %%
ensemble.price(product)

# %%
def ensemble_pricer(item):
    return max(0,ensemble.price(description(item)))

# %%
Tester.test(ensemble_pricer, test)
